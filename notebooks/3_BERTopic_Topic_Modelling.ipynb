# %% [markdown]
# Import the packages

# %%
import pandas as pd
import numpy as np
import joblib

# %% [markdown]
# Mount to google drive

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Import the data

# %%
with open('/content/drive/My Drive/BT4222/cleaned_data.pkl', 'rb') as f:
    data = joblib.load(f)

# %% [markdown]
# For train data use 10,000 reviews

# %%
cleaned_text =[]
for i in range(10000):
    cleaned_text.extend(data['cleaned'].iloc[i])

# %% [markdown]
# # BERTopic

# %% [markdown]
# install BERTopic

# %%
# !pip install bertopic

# %%
pip install bertopic[visualization]
# Out:
# ...
#      |████████████████████████████████| 57 kB 4.3 MB/s
# WARNING: bertopic 0.9.4 does not provide the extra 'visualization'
# ...
#      |████████████████████████████████| 5.2 MB 20.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 79 kB 7.8 MB/s
# ...
#      |████████████████████████████████| 86 kB 1.9 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 18.5 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 19.5 MB/s
# ...
#      |████████████████████████████████| 77 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 895 kB 38.1 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 32.7 MB/s
# ...
#      |████████████████████████████████| 636 kB 42.0 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 44.0 MB/s
# ...

# %% [markdown]
# Import BERTopic

# %%
from bertopic import BERTopic

# %% [markdown]
# Import our trained model

# %%
with open('/content/drive/My Drive/BT4222/use_bert_topic.pkl', 'rb') as f:
    model = joblib.load(f)

# %% [markdown]
# Get the topic frequencies

# %%
model.get_topic_freq()
# Out:
#     Topic  Count
# 0      -1  10198
# 1       0    356
# 2       1    220
# 3       2    217
# 4       3    185
# 5       4    171
# 6       5    158
# 7       6    149
# 8       7    147
# 9       8    138
# 10      9    137

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Each topic's most relevant words

# %%
list_words = model.get_topic(0)
words =[]
lda = []
for i in list_words:
    words.insert(0,i[0])
    lda.insert(0,i[1])
plt.barh(words,lda)
plt.title('Topic Word Scores')
plt.ylabel('Word')
plt.xlabel('c-TF-IDF score')
plt.show()
plt.savefig('topic 0.png')

# %%
list_words = model.get_topic(1)
words =[]
lda = []
for i in list_words:
    words.insert(0,i[0])
    lda.insert(0,i[1])
plt.barh(words,lda)
plt.title('Topic Word Scores')
plt.ylabel('Word')
plt.xlabel('c-TF-IDF score')
plt.show()
plt.savefig('topic 1.png')

# %%
list_words = model.get_topic(2)
words =[]
lda = []
for i in list_words:
    words.insert(0,i[0])
    lda.insert(0,i[1])
plt.barh(words,lda)
plt.title('Topic Word Scores')
plt.ylabel('Word')
plt.xlabel('c-TF-IDF score')
plt.show()
plt.savefig('topic 2.png')

# %%
list_words = model.get_topic(3)
words =[]
lda = []
for i in list_words:
    words.insert(0,i[0])
    lda.insert(0,i[1])
plt.barh(words,lda)
plt.title('Topic Word Scores')
plt.ylabel('Word')
plt.xlabel('c-TF-IDF score')
plt.show()
plt.savefig('topic 3.png')

# %%
list_words = model.get_topic(4)
words =[]
lda = []
for i in list_words:
    words.insert(0,i[0])
    lda.insert(0,i[1])
plt.barh(words,lda)
plt.title('Topic Word Scores')
plt.ylabel('Word')
plt.xlabel('c-TF-IDF score')
plt.show()
plt.savefig('topic 4.png')

# %%
list_words = model.get_topic(5)
words =[]
lda = []
for i in list_words:
    words.insert(0,i[0])
    lda.insert(0,i[1])
plt.barh(words,lda)
plt.title('Topic Word Scores')
plt.ylabel('Word')
plt.xlabel('c-TF-IDF score')
plt.show()
plt.savefig('topic 5.png')

# %%
list_words = model.get_topic(6)
words =[]
lda = []
for i in list_words:
    words.insert(0,i[0])
    lda.insert(0,i[1])
plt.barh(words,lda)
plt.title('Topic Word Scores')
plt.ylabel('Word')
plt.xlabel('c-TF-IDF score')
plt.show()
plt.savefig('topic 6.png')

# %%
list_words = model.get_topic(7)
words =[]
lda = []
for i in list_words:
    words.insert(0,i[0])
    lda.insert(0,i[1])
plt.barh(words,lda)
plt.title('Topic Word Scores')
plt.ylabel('Word')
plt.xlabel('c-TF-IDF score')
plt.show()
plt.savefig('topic 7.png')

# %%
list_words = model.get_topic(8)
words =[]
lda = []
for i in list_words:
    words.insert(0,i[0])
    lda.insert(0,i[1])
plt.barh(words,lda)
plt.title('Topic Word Scores')
plt.ylabel('Word')
plt.xlabel('c-TF-IDF score')
plt.show()
plt.savefig('topic 8.png')

# %%
list_words = model.get_topic(9)
words =[]
lda = []
for i in list_words:
    words.insert(0,i[0])
    lda.insert(0,i[1])
plt.barh(words,lda)
plt.title('Topic Word Scores')
plt.ylabel('Word')
plt.xlabel('c-TF-IDF score')
plt.show()
plt.savefig('topic 9.png')

# %% [markdown]
# # Model training

# %%
model10_1000 = BERTopic(verbose=True, nr_topics=10, n_gram_range=(1, 3))
 
topics10_1000, probabilities10_1000 = model10_1000.fit_transform(cleaned_text)
# Out:
# Batches:   0%|          | 0/378 [00:00<?, ?it/s]
# 2022-04-06 01:49:20,686 - BERTopic - Transformed documents to Embeddings
# 2022-04-06 01:49:39,227 - BERTopic - Reduced dimensionality with UMAP
# 2022-04-06 01:49:39,902 - BERTopic - Clustered UMAP embeddings with HDBSCAN
# 2022-04-06 01:49:51,025 - BERTopic - Reduced number of topics from 210 to 11

# %%
for i in range(10):
    print("Topic", i, model10_1000.get_topic(i)[:10])
# Out:
# Topic 0 [('place', 0.11577718594137494), ('love', 0.06547093443118013), ('love place', 0.04081143854089029), ('location', 0.03460652290604502), ('recommend', 0.027721086856712693), ('place love', 0.02277952769638448), ('try', 0.01974924442582938), ('like', 0.017992732678420897), ('highly', 0.017673853031895805), ('highly recommend', 0.01673990055076326)]
# Topic 1 [('pizza', 0.1674762194763291), ('crust', 0.01845500979099767), ('nt', 0.014288018021609844), ('not', 0.012293639552303205), ('oven', 0.012229301237951158), ('order', 0.011456770824491147), ('pizza pizza', 0.01113297625710432), ('like', 0.010581099769473124), ('place', 0.010131260047028747), ('good', 0.009833178380917953)]
# ...

# %% [markdown]
# Save the model (later renamed to use_bert_topic.pkl)

# %%
joblib.dump(model10_1000, "/content/drive/My Drive/BT4222/BERTopic10_1000_bigram.pkl")
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/_index.py:126: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# ['/content/drive/My Drive/BT4222/BERTopic10_1000_bigram.pkl']

# %% [markdown]
# Code to predict topics of new data

# %%
# # libraries required
# !pip install bertopic
# !pip install bertopic[visualization]
# !pip install BERTopic
import joblib
from bertopic import BERTopic

with open('/content/drive/My Drive/BT4222/BERTopic10_1000_bigram.pkl', 'rb') as f:
    model = joblib.load(f)

# phrases is the dataframe that is after sentiment analysis
# Topic 0 : place
# Topic 1 : fnb
# Topic 2 : price
# Topic 3 : service
def predict_topic(phrases, model):
    lst_topics = []
    sentences = phrases['Sentence']
    for i in sentences:
        idx = model.find_topics(i, top_n = 1)[0][0]
        if idx in [1,4,5,8,9]:
            lst_topics.append("Food and Beverage")
        elif (idx == 0) or (idx == 2):
            lst_topics.append("Place")
        elif idx == 6:
            lst_topics.append("Service")
        else:
            lst_topics.append("Price")
    df = phrases.copy()
    df['Topic'] = lst_topics
    return df
# Out:
# ...
#      |████████████████████████████████| 57 kB 3.8 MB/s
# ...
#      |████████████████████████████████| 5.2 MB 18.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 79 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 86 kB 5.7 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 32.3 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 62.1 MB/s
# ...
#      |████████████████████████████████| 77 kB 6.1 MB/s
# ...
#      |████████████████████████████████| 895 kB 53.8 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 38.6 MB/s
# ...
#      |████████████████████████████████| 636 kB 62.5 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 62.6 MB/s
# ...
#   Created wheel for hdbscan: filename=hdbscan-0.8.28-cp37-cp37m-linux_x86_64.whl size=2330856 sha256=84b5be7d71ea70301b7126122ac8b7954fedfbe0d9623f486e8797f792cfedee
# ...
